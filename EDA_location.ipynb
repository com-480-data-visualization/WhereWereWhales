# %% [markdown]
# ## Habitat and Distribution of Cetacea: Happy Whales Dataset

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <strong><a href="https://happywhale.com/home">HappyWhale</a></strong> and  <strong><a href="https://seamap.env.duke.edu/">OBIS Seamap</a></strong> are platforms that aggregate cetacean sighting data from various regions around the world, contributed by citizen scientists.
# </div>

# %%
import pandas as pd
from utils import extract_unique, load_happywhales_data, group_species

df_location = load_happywhales_data()
df_location.head(3)
# Out:
#    dataset_id       row_id   latitude   longitude        species_name  \
# 0        1692  1692_106512  36.800955 -121.793890  Bottlenose Dolphin
# 1        1692  1692_108158  33.573770 -117.977927  Bottlenose Dolphin
# 2        1692  1692_108285  33.900000 -118.500000  Bottlenose Dolphin
#
#       scientific_name         common_name  itis_tsn  \
# 0  Tursiops truncatus  Bottlenose Dolphin    180426
# 1  Tursiops truncatus  Bottlenose Dolphin    180426
# 2  Tursiops truncatus  Bottlenose Dolphin    180426
#
#                                               oceano  individual_count  sex  \
# 0  {"SSH": {"AVISO": {"8DAYS": 58.76}}, "SST": {"...               1.0  NaN
# 1  {"SST": {"HYCOM": {"YEAR": 17.49, "MONTH": 17....               1.0  NaN
# 2  {"SST": {"HYCOM": {"YEAR": 17.96, "MONTH": 20....               1.0  NaN
#
#   organism_id  event_date higher_geography           water_body  \
# 0         NaN  2024-07-22    North Pacific  North Pacific Ocean
# 1        3533  2017-06-23    North Pacific  North Pacific Ocean
# 2        3533  2017-10-28    North Pacific  North Pacific Ocean
#
#                     locality               verbatim_locality date_time
# 0  California, United States                Monterey Bay, CA       NaN
# 1  California, United States  3 miles off Main beach, Laguna       NaN
# 2  California, United States                             NaN       NaN

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import geodatasets
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from utils import parse_individual_count

geometry = [Point(xy) for xy in zip(df_location['longitude'], df_location['latitude'])]
gdf = GeoDataFrame(df_location, geometry=geometry)   

world = gpd.read_file(geodatasets.data.naturalearth.land['url'])

fig, ax = plt.subplots(figsize=(10, 6))
world.plot(ax=ax, color="lightgrey")

marker_size = gdf['individual_count'].fillna(1)
marker_size = marker_size**0.5 * 5 

species_list = gdf['species_name'].unique()
colors = list(mcolors.TABLEAU_COLORS.values())  # Get a list of Tableau colors
species_colors = {species: colors[i % len(colors)] for i, species in enumerate(species_list)}

gdf['color'] = gdf['species_name'].map(species_colors)  # Map species to colors
gdf.plot(ax=ax, marker='o', color=gdf['color'], markersize=marker_size, alpha=0.6, edgecolor='black')

handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in list(species_colors.values())]
labels = species_list
ax.legend(handles, labels, title="Species", loc="upper left", fontsize=8, bbox_to_anchor=(1.05, 1), ncol=2)

plt.title("Cetacean Sightings")
plt.show()

# %%
LAT_LONG_THRESHOLD = 2
grouped_species = group_species(df_location, LAT_LONG_THRESHOLD)
# Out:
# 100%|██████████| 123/123 [00:11<00:00, 10.49it/s]

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import geodatasets


geometry = [Point(xy) for xy in zip(grouped_species['longitude'], grouped_species['latitude'])]
gdf = GeoDataFrame(grouped_species, geometry=geometry)

species_list = gdf['species_name'].unique()
colors =  px.colors.sequential.YlGnBu[2:9] + px.colors.sequential.Greens_r[0:1] + px.colors.sequential.Greens_r[2:5] + px.colors.sequential.OrRd_r[1:9]
species_colors = {species: colors[i % len(colors)] for i, species in enumerate(species_list)}

gdf['color'] = gdf['species_name'].map(species_colors)

fig = go.Figure()

for species in species_list:
    species_data = gdf[gdf['species_name'] == species]
    fig.add_trace(go.Scattergeo(
        lat=species_data['latitude'],
        lon=species_data['longitude'],
        text=species_data['species_name'],
        marker=dict(
            size=(species_data['individual_count'].fillna(1)*5).clip(lower=5, upper=15), 
            color=species_data['color'], 
            opacity=0.6,
            line=dict(width=1, color='black')
        ),
        name=species, 
        mode='markers'
    ))

fig.update_geos(
    projection_type="mercator",
    showland=True,
    landcolor="lightgrey",
    showlakes=True,
    lakecolor="white"
)

fig.update_layout(
    title="Cetacean Sightings by Species",
    geo=dict(
        scope='world',
        projection_type='mercator',
        landcolor='lightgrey'
    ),
    legend_title="Species",
    legend=dict(
        itemsizing='constant',
        title='Species',
        x=1.05,
        y=1
    ),
    showlegend=True,
    height=800,
)

fig.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from utils import extract_unique

df_location_unique = extract_unique(df_location) # extract unique animals

df_location_unique['event_date'] = pd.to_datetime(df_location_unique['event_date'], errors='coerce')
df_location_unique['year'] = df_location_unique['event_date'].dt.year
sightings_per_year = df_location_unique.groupby('year').size().reset_index(name='sightings_count')

fig, axes = plt.subplots(2, 1, figsize=(15, 10))

# First subplot: Number of Sighting Events Per Year
sns.barplot(x='year', y='sightings_count', data=sightings_per_year, color='skyblue', ax=axes[0])
axes[0].set_title('Number of Unique Observed Events Per Year', fontsize=14)
axes[0].set_xlabel('Year', fontsize=12)
axes[0].set_ylabel('Number of Sightings', fontsize=12)
axes[0].tick_params(axis='x', rotation=45, labelsize=10)

# Second subplot: Distribution of Sightings by Higher Geography
df_location_unique = df_location_unique.dropna(subset=['higher_geography'])
sns.countplot(y='higher_geography', data=df_location_unique, order=df_location_unique['higher_geography'].value_counts().index[:10], color='dodgerblue', ax=axes[1])
axes[1].set_title('Distribution of Unique Sightings for top 10 Higher Geography', fontsize=12)
axes[1].set_xlabel('Number of Sightings', fontsize=12)
axes[1].set_ylabel('Geographical Region', fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\camil\AppData\Local\Temp\ipykernel_1632\4234732157.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\camil\AppData\Local\Temp\ipykernel_1632\4234732157.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## An Endangered Species: The Decline of Cetacean Populations

# %%
# TODO

# %% [markdown]
# ## Multiple Threats: Challenges to Cetacean Survival

# %% [markdown]
# ### A- Climate disruption

# %% [markdown]
# <div class="alert alert-block alert-info">
# Large cetaceans migrate thousands of kilometers to feed on krill in high latitudes, but climate change is disrupting these feeding grounds. As prey shifts and productivity declines, their ability to adapt remains uncertain.
#
#
# Data from <a href="https://marine.copernicus.eu/ocean-climate-portal/sea-surface-temperatures">Copernicus</a>
#
# Note : An anomaly is the difference from an average value, for example, the anomaly of January 2022 is calculated by the difference between the data value of the month of January in 2022 and the climatology of all the months of January over the time period covered.
# </div>

# %%
df_temperature = pd.read_csv("data\Copernicus_temperature.csv")
df_temperature['date'] = pd.to_datetime(df_temperature['date'])

plt.figure(figsize=(10, 6))
plt.plot(df_temperature['date'], df_temperature[' - values'], marker='o', color='dodgerblue', linestyle='-', linewidth=2, markersize=5)

plt.title("Global Monthly Average Sea Surface Temperature Anomalies", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Temperature Anomalies (°C)", fontsize=12)
plt.axhline(0, color='black', linestyle='--', linewidth=1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### B- Maritime traffic

# %% [markdown]
# <div class="alert alert-block alert-info">
# Intense maritime traffic increases the risk of ship collisions and adds constant underwater noise, disrupting cetaceans' vital sense of hearing.
#
# Data from IWCShip Strike Database (https://iwc.int/management-and-conservation/ship-strikes)
# </div>

# %%
df_traffic = pd.read_csv("data\ship_strikes_per_year.csv")
df_traffic.head(3)
# Out:
#    Year  Definite Count  Probable Count  Possible Count
# 0  1820               1               0               0
# 1  1954               1               0               0
# 2  1955               1               0               0

# %%
df_traffic = df_traffic[pd.to_numeric(df_traffic['Year'], errors='coerce').notna()]
df_traffic['Year'] = df_traffic['Year'].astype(int)

df_traffic["Total"] = df_traffic["Definite Count"] + df_traffic["Probable Count"] + df_traffic["Possible Count"]
full_years = pd.DataFrame({'Year': range(df_traffic['Year'].min(), df_traffic['Year'].max() + 1)})
df_traffic = full_years.merge(df_traffic, on='Year', how='left').fillna(0)

plt.figure(figsize=(12, 6))
sns.lineplot(x=df_traffic["Year"], y=df_traffic["Total"], marker="o", color="royalblue", linewidth=2)

plt.axhline(0, linestyle="dotted", color="black")

plt.xlabel("Year")
plt.ylabel("Total Ship Strikes")
plt.title("Evolution of Ship Strikes Over Time")
plt.grid(True, linestyle="--", alpha=0.5)

plt.show()

# %% [markdown]
# ### C- Pollution and Plastic contamination

# %% [markdown]
# <div class="alert alert-block alert-info">
# Chemical pollution has spread across the biosphere, accumulating in the food chain and harming cetaceans' health and fertility. Plastic pollution adds mechanical and chemical threats, entangling marine life and releasing harmful compounds into the ocean.
# </div>

# %% [markdown]
# ### D- Hunting

# %% [markdown]
# <div class="alert alert-block alert-info">
# Despite a moratorium and the ban on international whaling trade, nearly 1,000 whales are killed annually for commercial purposes. Three countries: Norway, Japan, and Iceland, continue to hunt whales for commercial reasons.
#
#
# Data from the <a href="https://iwc.int/management-and-conservation/whaling/total-catches">International Whaling Commission</a>
#
# Nb : Type of operation. C: Commercial; A: Aboriginal; I: Illegal;  S: special permit;      -: no catch; Co: Commercial under objection; Cr: Commercial under reservation
#
# </div>

# %%
df = pd.read_excel('data\\direct-catches-summary-data-since-1986.xlsx', sheet_name="data", header=0)
df
# Out:
#      Year  Ty          Area                          Nation  Fin  Sperm  \
# 0    1986   A      Alaska N                   United States    0      0
# 1    1986   A      Chukotka                            USSR    0      0
# 2    1986   A   Greenland E               Denmark/Greenland    0      0
# 3    1986   A  Greenland W.               Denmark/Greenland    9      0
# 4    1986   A     W. Indies  Saint Vincent & the Grenadines    0      0
# ..    ...  ..           ...                             ...  ...    ...
# 436  2023  Cr    Iceland W.                         Iceland   24      0
# 437  2023   I   Greenland E               Denmark/Greenland    0      0
# 438  2023   I  Greenland W.               Denmark/Greenland    0      0
# 439  2023   I         Korea                           Korea    0      0
# 440  2024   A     W. Indies  Saint Vincent & the Grenadines    0      0
#
#      Humpback  Sei  Brydes  CommonMinke  AntarcticMinke  Gray  Bowhead  Total
# 0           0    0       0            0               0     2       28     30
# 1           0    0       0            0               0   169        0    169
# 2           0    0       0            2               0     0        0      2
# 3           0    0       0          145               0     0        0    154
# 4           2    0       0            0               0     0        0      2
# ..        ...  ...     ...          ...             ...   ...      ...    ...
# 436         0    0       0            0               0     0        0     24
# 437         1    0       0            0               0     0        0      1
# 438         0    0       0            1               0     0        0      1
# 439         0    0       0           17               0     0        0     17
# 440         1    0       0            0               0     0        0      1
#
# [441 rows x 14 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

type_mapping = {
    'C': 'Commercial',
    'A': 'Aboriginal',
    'I': 'Illegal',
    'S': 'Special Permit',
    '-': 'No Catch',
    'Co': 'Commercial under Objection',
    'Cr': 'Commercial under Reservation'
}

df['Ty_full'] = df['Ty'].map(type_mapping)

operation_counts = df['Ty_full'].value_counts()

plt.figure(figsize=(8, 6))
operation_counts.plot(kind='bar', color='#4682b4', edgecolor='darkblue')

plt.title("Distribution of Whale Catch Operations", fontsize=16)
plt.xlabel("Operation Types", fontsize=12)
plt.ylabel("Number of Catches", fontsize=12)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

species_columns = ['Fin', 'Sperm', 'Humpback', 'Sei', 'Brydes', 'CommonMinke', 'AntarcticMinke', 'Gray', 'Bowhead']
palette = sns.color_palette("mako", n_colors=len(species_columns))
df_yearly_catches = df.groupby('Year')[species_columns].sum()

plt.figure(figsize=(10, 6))
df_yearly_catches.plot(kind='area', stacked=True, figsize=(10, 6), color=palette)

plt.title('Evolution of Whale Catches Per Year by Species since the Moratorium came into place in 1985', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Catches', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Species', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

species_columns = ['Fin', 'Sperm', 'Humpback', 'Sei', 'Brydes', 'CommonMinke', 'AntarcticMinke', 'Gray', 'Bowhead', "Total"]

df_country_catches = df.groupby('Nation')[species_columns].sum()
# df_country_catches = df_country_catches.reset_index()

# # Sort countries by total catches in descending order
df_country_catches = df_country_catches.sort_values('Total', ascending=True)
df_country_catches = df_country_catches.drop("Total", axis=1)

# # Plot the stacked bar chart using seaborn
plt.figure(figsize=(12, 8))
df_country_catches.plot(kind='barh', stacked=True, color=palette, figsize=(12, 5), width=0.8)

for index, value in enumerate(df_country_catches['Fin']):  # Use 'Fin' or any column for y position
    ax.text(df_country_catches.iloc[index, 0], index, df_country_catches.iloc[index, 0], va='center', fontsize=10, color='black')

# Customize plot
plt.title('Total Whale Catches by Species and Country from 1985 to 2024', fontsize=16)
plt.xlabel('Total Catches (Number of Whales)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ## Solution : Protected areas

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img src="data/map.png" alt="Marine Mammal Habitat Map" style="max-width: 1000px; height: auto; border-radius: 5px;">
#     <div>
#         <p>Explore more about marine mammal habitats at:</p><a href="https://www.marinemammalhabitat.org/">www.marinemammalhabitat.org</a>
#     </div>
# </div>

# %%
df = pd.read_csv("data\INMA.csv")
species_list = ", ".join(df["Qualifying Species"].dropna()) + ", " + ", ".join(df["Supporting Species"].dropna())

def transform_to_list(species_str):
    if isinstance(species_str, str): 
        return [s.strip() for s in species_str.split(".")]  # Strip spaces and split at '.'
    return []  

df["Qualifying Species"] = df["Qualifying Species"].apply(transform_to_list)
df["Supporting Species"] = df["Supporting Species"].apply(transform_to_list)

df
# Out:
#     Area status                                             Region  \
# 0          IMMA  Australia-New Zealand and South East Indian Ocean
# 1          IMMA  Australia-New Zealand and South East Indian Ocean
# 2          IMMA  Australia-New Zealand and South East Indian Ocean
# 3          IMMA  Australia-New Zealand and South East Indian Ocean
# 4          IMMA  Australia-New Zealand and South East Indian Ocean
# ..          ...                                                ...
# 514         AoI      North West Atlantic Ocean and Wider Caribbean
# 515         AoI      North West Atlantic Ocean and Wider Caribbean
# 516         AoI      North West Atlantic Ocean and Wider Caribbean
# 517         AoI      North West Atlantic Ocean and Wider Caribbean
# 518         AoI      North West Atlantic Ocean and Wider Caribbean
#
#                                                  Title  \
# 0    Geographe Bay to Eucla Shelf and Coastal Water...
# 1    Southern Australian Coastal and Shelf Region IMMA
# 2    Southeastern Australian and Tasmanian Shelf Wa...
# 3        Australian East Coast Migration Corridor IMMA
# 4    Coast and Shelf Waters of Eastern Te Waipounam...
# ..                                                 ...
# 514                             Golfe de la Gonâve AoI
# 515     Eastern Caribbean Windward Offshore Waters AoI
# 516             Panama-Costa Rica Manatee Corridor AoI
# 517            Southern Gulf of Mexico Inner Shelf AoI
# 518                               Cordillera Beata AoI
#
#                                                Details  \
# 0    <a data-content="Read full IMMA summary" href=...
# 1    <a data-content="Read full IMMA summary" href=...
# 2    <a data-content="Read full IMMA summary" href=...
# 3    <a data-content="Read full IMMA summary" href=...
# 4    <a data-content="Read full IMMA summary" href=...
# ..                                                 ...
# 514  <a data-content="Requires more data" href="htt...
# 515  <a data-content="Requires more data" href="htt...
# 516  <a data-content="Requires more data" href="htt...
# 517  <a data-content="Requires more data" href="htt...
# 518  <a data-content="Requires more data" href="htt...
#
#                                      Criteria  \
# 0                           A, B2, C1, C2, C3
# 1                   A, B2, C1, C2, C3, D1, D2
# 2                   A, B1, B2, C1, C2, C3, D2
# 3                                      C3, D1
# 4                                       A, B1
# ..                                        ...
# 514  Unconfirmed - pending further assessment
# 515  Unconfirmed - pending further assessment
# 516  Unconfirmed - pending further assessment
# 517  Unconfirmed - pending further assessment
# 518  Unconfirmed - pending further assessment
#
#                                     Qualifying Species  \
# 0    [Eubalaena australis, Megaptera novaeangliae, ...
# 1    [Neophoca cinerea, Arctocephalus forsteri, Eub...
# 2    [Balaenoptera musculus, Arctocephalus forsteri...
# 3    [Megaptera novaeangliae, Balaenoptera acutoros...
# 4        [Cephalorhynchus hectori, Phocarctos hookeri]
# ..                                                 ...
# 514         [Unconfirmed - pending further assessment]
# 515         [Unconfirmed - pending further assessment]
# 516         [Unconfirmed - pending further assessment]
# 517         [Unconfirmed - pending further assessment]
# 518         [Unconfirmed - pending further assessment]
#
#                                     Supporting Species  \
# 0    [Tursiops aduncus, Delphinus delphis, Balaenop...
# 1    [Megaptera novaeangliae, Balaenoptera borealis...
# 2    [Delphinus delphis, Tursiops truncatus, Tursio...
# 3    [Orcaella heinsohni, Sousa sahulensis, Dugong ...
# 4    [Megaptera novaeeangliae, Eubalaena australis,...
# ..                                                 ...
# 514  [Balaenoptera acutorostrata, Globicephala macr...
# 515                           [Megaptera novaeangliae]
# 516                       [Trichechus manatus manatus]
# 517  [Tursiops truncatus, Trichechus manatus manatu...
# 518  [Globicephala macrorhynchus, Megaptera novaean...
#
#                                           jurisdiction
# 0                                            Australia
# 1                                           Austrialia
# 2                                            Australia
# 3                                            Australia
# 4                                          New Zealand
# ..                                                 ...
# 514                                        Haiti, Cuba
# 515  Antigua and Barbuda, Dominica, Barbados, Guade...
# 516                                 Panama, Costa Rica
# 517                                             Mexico
# 518  Haiti, Dominican Republic, Colombia, Venezuela...
#
# [519 rows x 8 columns]

# %%
df["Supporting Species"]
# Out:
# 0      Tursiops aduncus, Delphinus delphis, Balaenopt...
# 1      Megaptera novaeangliae, Balaenoptera borealis,...
# 2      Delphinus delphis, Tursiops truncatus, Tursiop...
# 3      Orcaella heinsohni, Sousa sahulensis, Dugong d...
# 4      Megaptera novaeeangliae, Eubalaena australis, ...
#                              ...
# 514    Balaenoptera acutorostrata, Globicephala macro...
# 515                               Megaptera novaeangliae
# 516                           Trichechus manatus manatus
# 517    Tursiops truncatus, Trichechus manatus manatus...
# 518    Globicephala macrorhynchus, Megaptera novaeang...
# Name: Supporting Species, Length: 519, dtype: object

# %%
# Out:
# ['Eubalaena australis',
#  'Megaptera novaeangliae',
#  'Balaenoptera musculus',
#  'Neophoca cinerea',
#  'Arctocephalus forsteri']

# %%
species_list
# Out:
# 'Eubalaena australis, Megaptera novaeangliae, Balaenoptera musculus, Neophoca cinerea, Arctocephalus forsteri,Neophoca cinerea, Arctocephalus forsteri, Eubalaena australis, Balaenoptera musculus, Arctocephalus pusillus,Balaenoptera musculus, Arctocephalus forsteri, Arctocephalus pusillus, Eubalaena australis, Megaptera novaeangliae,Megaptera novaeangliae, Balaenoptera acutorostrata,Cephalorhynchus hectori, Phocarctos hookeri,Balaenoptera musculus, Berardius arnuxii, Ziphius cavirostris, Lagenorhynchus obscurus, Mesoplodon grayi, Cephalorhynchus hectori, Megaptera novaeangliae, Orcinus orca, Arctocephalus forsteri, Phocarctos hookeri,Cephalorhynchus hectori, Balaenoptera musculus, Arctocephalus forsteri, Megaptera novaeangliae, Balaenoptera physalus, Balaenoptera borealis, Physeter macrocephalus,Cephalorhynchus hectori, Balaenoptera musculus, Arctocephalus forsteri,Balaenoptera edeni, Pseudorca crassidens, Balaenoptera musculus,Megaptera novaeangliae,Balaenoptera musculus, Balaenoptera physalus, Cephalorhynchus hectori, Megaptera novaeangliae, Arctocephalus forsteri, Phocarctos hookeri, Bal
#  'Unconfirmed - pending further assessment,Balaenoptera edeni, Globicephala macrorhynchus, Kogia breviceps, Kogia sima, Neophocaena phocaenoides, Sousa chinensis, Stenella longirostris, Steno bredanensis, Pseudorca crassidens, Tursiops aduncus, Ziphius cavirostris',
#  'Unconfirmed - pending further assessment,Orcinus orca, Physeter macrocephalus, Stenella longirostris, Kogia sima, Kogia breviceps, Steno bredanensis, Tursiops aduncus, Pseudorca crassidens, Lagenodelphis hosei',
#  'Unconfirmed - pending further assessment,Sousa chinensis, Orcaella brevirostris, Tursiops aduncus, Neophocaena phocaenoides, Dugong dugon, Balaenoptera edeni',
#  'Unconfirmed - pending further assessment,Balaenoptera edeni, Grampus griseus, Globicephala macrorhynchus, Lagenodelphis hosei, Stenella attenuata, Stenella longirostris',
#  'Unconfirmed - pending further assessment,Dugong dugon, Orcaella brevirostris, Sousa chinensis, Tursiops aduncus, Neophocaena phocaenoides',
#  'Unconfirmed - pending further assessment,Tursiops aduncus, Neophocaena phocaenoides, Stenella longirostris, Delphinus delphis, Dugong dugon',
#  'Unconfirmed - pending further assessment,Sousa chinensis, Neophocaena phocaenoides, Tursiops aduncus, Stenella longirostris, Stenella attenuata',
#  'Unconfirmed - pending further assessment,Sousa chinensis, Neophocaena phocaenoides, Tursiops aduncus, Stenella longirostris, Stenella attenuata',
#  'Unconfirmed - pending further assessment,Orcaella brevirostris, Neophocaena phocaenoides, Sousa chinensis, Tursiops aduncus, Balaenoptera edeni',
#  'Unconfirmed - pending further assessment,Balaenoptera musculus, Balaenoptera edeni, Dugong dugon, Megaptera novaeangliae, Orcinus orca',
#  'Unconfirmed - pending further assessment,Dugong dugon, Sousa chinensis, Tursiops aduncus, Orcaella brevirostris',
#  'Unconfirmed - pending further assessment,Dugong dugon, Physeter macrocephalus, Lagenodelphis hosei',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Kogia sima, Lagenodelphis hosei',
#  'Unconfirmed - pending further assessment,Orcaella brevirostris, Sousa chinensis, Neophocaena phocaenoides',
#  'Unconfirmed - pending further assessment,Balaenoptera edeni, Neophocaena phocaenoides, Orcaella brevirostris, Sousa chinensis',
#  'Unconfirmed - pending further assessment,Neophocaena phocaenoides, Orcaella brevirostris, Sousa chinensis',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Sousa sahulensis, Dugong dugon',
#  'Unconfirmed - pending further assessment,Orcaella brevirostris, Sousa chinensis, Dugong dugon',
#  'Unconfirmed - pending further assessment,Balaenoptera physalus, Dugong dugon',
#  'Unconfirmed - pending further assessment,Tursiops aduncus, Neophocaena phocaenoides',
#  'Unconfirmed - pending further assessment,Balaenoptera musculus, Stenella longirostris',
#  'Unconfirmed - pending further assessment,Tursiops aduncus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Balaenoptera musculus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Orcaella brevirostris',
#  'Unconfirmed - pending further assessment,Tursiops truncatus',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Orcaella brevirostris',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Dugong dugon',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Ziphius cavirostris',
#  'Unconfirmed - pending further assessment,Tursiops truncatus, Stenella longirostris, Physeter macrocephalus, Orcinus orca, Megaptera novaeangliae, Globicephala macrorhynchus, Balaenoptera musculus intermedia, Dugong dugon, Lagenodelphis hosei, Pseudorca crassidens',
#  'Unconfirmed - pending further assessment,Tursiops truncatus, Stenella longirostris, Physeter macrocephalus, Orcinus orca, Megaptera novaeangliae, Globicephala macrorhynchus, Balaenoptera musculus intermedia, Dugong dugon',
#  'Unconfirmed - pending further assessment,Tursiops truncatus, Stenella longirostris, Physeter macrocephalus, Megaptera novaeangliae, Globicephala macrorhynchus, Balaenoptera musculus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Kogia sima, Lagenodelphis hosei, Pseudorca crassidens, Megaptera novaeangliae, Globicephala macrorhynchus',
#  'Unconfirmed - pending further assessment,Tursiops truncatus, Globicephala macrorhynchus, Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae, Balaenoptera borealis, Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Stenella longirostris, Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Delphinus delphis, Tursiops truncatus, Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Stenella longirostris, Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Dugong dugon, Megaptera novaeangliae, Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae, Mesoplodon densirostris',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae, Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Stenella longirostris',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Ziphius cavirostris',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Tursiops truncatus',
#  'Unconfirmed - pending further assessment,Stenella longirostris',
#  'Unconfirmed - pending further assessment,Balaenoptera musculus, Megaptera novaeangliae, Physeter macrocephalus, Ziphius cavirostris, Mesoplodon densirostris, Pseudorca crassidens, Tursiops truncatus, Mirounga leonina',
#  'Unconfirmed - pending further assessment,Balaenoptera bonaerensis, Cephalorhynchus eutropia, Lagenorhynchus australis, Orcinus orca, Otaria byronia',
#  'Unconfirmed - pending further assessment,Tursiops truncatus',
#  'Unconfirmed - pending further assessment,Physeter macrocephalus, Stenella frontalis, Stenella attenuata, Stenella longirostris, Globicephala macrorhynchus, Pseudorca crassidens, Stenella clymene, Orcinus orca, Steno bredanensis, Tursiops truncatus, Balaenoptera physalus, Balaenoptera edeni',
#  'Unconfirmed - pending further assessment,Tursiops truncatus',
#  'Unconfirmed - pending further assessment,Balaenoptera brydei, Feresa attenuata, Globicephala macrorhynchus, Grampus griseus, Kogia breviceps, Kogia sima, Lagenodelphis hosei, Mesoplodon densirostris, Mesoplodon europaeus, Orcinus orca, Peponocephala electra, Physeter macrocephalus, Pseudorca crassidens, Stenella attenuata, Stenella clymene, Stenella coeruleoalba, Stenella frontalis, Stenella longirostris, Steno bredanensis, Tursiops Truncatus, Ziphius cavirostris',
#  'Unconfirmed - pending further assessment,Balaenoptera acutorostrata, Globicephala macrorhynchus, Grampus griseus, Kogia sima, Megaptera novaeangliae, Orcinus orca, Physeter macrocephalus, Pseudorca crassidens, Stenella attenuata, Steno bredanensis, Trichechus manatus manatus, Tursiops truncatus, Ziphius cavirostris',
#  'Unconfirmed - pending further assessment,Megaptera novaeangliae',
#  'Unconfirmed - pending further assessment,Trichechus manatus manatus',
#  'Unconfirmed - pending further assessment,Tursiops truncatus, Trichechus manatus manatus, Balaenoptera ricei',
#  'Unconfirmed - pending further assessment,Globicephala macrorhynchus, Megaptera novaeangliae, Orcinus orca, Physeter macrocephalus, Pseudorca crassidens, Stenella frontalis, Stenella attenuata, Steno bredanensis']

# %%
species_set
# Out:
# {'  Tursiops aduncus',
#  '  Ziphius cavirostris',
#  ' Arctocephalus australis',
#  ' Arctocephalus forsteri',
#  ' Arctocephalus gazella',
#  ' Arctocephalus philippii',
#  ' Arctocephalus philippii townsendi',
#  ' Arctocephalus pusillus',
#  ' Arctocephalus tropicalis',
#  ' Balaenoptera acurostrata',
#  ' Balaenoptera acutorostrata',
#  ' Balaenoptera acutorostrata ',
#  ' Balaenoptera bonaerensis',
#  ' Balaenoptera borealis',
#  ' Balaenoptera brydei',
#  ' Balaenoptera edeni',
#  ' Balaenoptera musculus',
#  ' Balaenoptera musculus brevicauda',
#  ' Balaenoptera musculus intermedia',
#  ' Balaenoptera omurai',
#  ' Balaenoptera physalus',
#  ' Balaenoptera ricei',
#  ' Balenoptera physalus',
#  ' Berardius arnuxii',
#  ' Berardius bairdii',
#  ' Caperea marginata',
#  ' Cephalorhynchus commersonii',
#  ' Cephalorhynchus commersonii commersonii',
#  ' Cephalorhynchus eutropia',
#  ' Cephalorhynchus hectori',
#  ' Cystophora cristata',
#  ' Cystophora crystata',
#  ' Delphinapterus leucas',
#  ' Delphinus delphis',
#  ' Delphinus delphis delphis',
#  ' Delphinus delphis ponticus',
#  ' Delphinus delphis tropicalis',
#  ' Dugong dugon',
#  ' Eschrichtius robustus',
#  ' Eubalaena australis',
#  ' Eubalaena glacialis',
#  ' Eubalaena japonica',
#  ' Feresa attenuata',
#  ' Globicephala macrorhynchus',
#  ' Globicephala melas',
#  ' Globicephala melas edwardi',
#  ' Globicephala melas edwardii',
#  ' Grampus griseus',
#  ' Halichoerus grypus',
#  ' Halichoerus grypus atlantica',
#  ' Hydrurga leptonyx',
#  ' Hyperoodon ampullatus',
#  ' Hyperoodon planifrons',
#  ' Indopacetus pacificus',
#  ' Kogia breviceps',
#  ' Kogia sima',
#  ' Kogia spp.',
#  ' Lagenodelphis hosei',
#  ' Lagenorhynchus acutus',
#  ' Lagenorhynchus acutus ',
#  ' Lagenorhynchus acutus Globicephala melas',
#  ' Lagenorhynchus albirostris',
#  ' Lagenorhynchus australis',
#  ' Lagenorhynchus cruciger',
#  ' Lagenorhynchus obliquidens',
#  ' Lagenorhynchus obscurus',
#  ' Lagenorhyncus albirostris',
#  ' Leptonychotes weddellii',
#  ' Lissodelphis peronii',
#  ' Lobodon carcinophaga',
#  ' Lontra felina',
#  ' Lontra longicaudis',
#  ' Lontra provocax',
#  ' Megaptera novaeangliae',
#  ' Megaptera novaengliae',
#  ' Mesoplodon bidens',
#  ' Mesoplodon bowdoini',
#  ' Mesoplodon densirostris',
#  ' Mesoplodon europaeus',
#  ' Mesoplodon europeaeus',
#  ' Mesoplodon ginkgoden',
#  ' Mesoplodon grayi',
#  ' Mesoplodon hotaula',
#  ' Mesoplodon layardii',
#  ' Mesoplodon mirus',
#  ' Mesoplodon peruvianus',
#  ' Mesoplodon spp',
#  ' Mirounga angustirostris',
#  ' Mirounga leonina',
#  ' Monachus monachus',
#  ' Neophoca cinerea',
#  ' Neophocaena phocaenoides',
#  ' Ommatophoca rossii',
#  ' Orcaella brevirostris',
#  ' Orcaella heinsohni',
#  ' Orcinus orca',
#  ' Oricinus orca',
#  ' Otaria byronia',
#  ' Pagophilus groenlandicus',
#  ' Peponocephala electra',
#  ' Phoca vitulina',
#  ' Phoca vitulina richardii',
#  ' Phoca vitulina vitulina',
#  ' Phocarctos hookeri',
#  ' Phocoena dioptrica',
#  ' Phocoena phocoena',
#  ' Phocoena phocoena relicta',
#  ' Phocoena sinus',
#  ' Phocoena spinipinnis',
#  ' Physeter macrocephalus',
#  ' Physeter microcephalus',
#  ' Platanista gangetica',
#  ' Pontoporia blainvillei',
#  ' Pseudorca crassidens',
#  ' Pteronura brasiliensis',
#  ' Senella coeruleoalba',
#  ' Sotalia guianensis',
#  ' Sousa chinensis',
#  ' Sousa plumbea',
#  ' Sousa sahulensis',
#  ' Stenella attenuata',
#  ' Stenella attenuate',
#  ' Stenella clymene',
#  ' Stenella coeruleoalba',
#  ' Stenella frontalis',
#  ' Stenella longirostris',
#  ' Stenella longirostris longirostris',
#  ' Stenella longirostris orientalis',
#  ' Steno bredanensis',
#  ' Tasmacetus shepherdi',
#  ' Trichechus inunguis',
#  ' Trichechus manatus',
#  ' Trichechus manatus manatus',
#  ' Tursiops Truncatus',
#  ' Tursiops aduncus',
#  ' Tursiops erebennus',
#  ' Tursiops truncatus',
#  ' Tursiops truncatus gephyreus',
#  ' Tursiops truncatus ponticus',
#  ' Tursiops truncatus truncatus',
#  ' Ursus maritimus',
#  ' Zalophus californianus',
#  ' Zalophus wollebaeki',
#  ' Ziphius cavirostris',
#  ' Ziphius cavirostris ',
#  ' phocoena phocoena',
#  '...',
#  'Arctocephalus australis',
#  'Arctocephalus forsteri',
#  'Arctocephalus galapagoensis',
#  'Arctocephalus gazella',
#  'Arctocephalus philippii',
#  'Arctocephalus tropicalis',
#  'Balaenoptera acutorostrata',
#  'Balaenoptera bonaerensis',
#  'Balaenoptera borealis',
#  'Balaenoptera brydei',
#  'Balaenoptera edeni',
#  'Balaenoptera musculus',
#  'Balaenoptera omurai',
#  'Balaenoptera physalus',
#  'Balaenoptera physalus physalus',
#  'Balaenoptera ricei',
#  'Berardius arnuxii',
#  'Cephalorhynchus commersonii',
#  'Cephalorhynchus eutropia',
#  'Cephalorhynchus hectori',
#  'Delphinapterus leucas',
#  'Delphinus delphis',
#  'Delphinus delphis ponticus',
#  'Delphinus delphis tropicalis',
#  'Dugong dugon',
#  'Eschrichtius robustus',
#  'Eubalaena australis',
#  'Eubalaena glacialis',
#  'Feresa attenuata',
#  'Globicephala macrorhynchus',
#  'Globicephala melas',
#  'Grampus griseus',
#  'Halichoerus grypus',
#  'Hydrurga leptonyx',
#  'Indopacetus pacificus',
#  'Inia geoffrensis',
#  'Kogia breviceps',
#  'Kogia sima',
#  'Lagenorhynchus acutus',
#  'Lagenorhynchus albirostris',
#  'Lagenorhynchus australis',
#  'Lagenorhynchus obscurus',
#  'Leptonychotes weddellii',
#  'Lobodon carcinophaga',
#  'Lontra felina',
#  'Megaptera novaeangliae',
#  'Megaptera novaeangliae australis',
#  'Megaptera novaeeangliae',
#  'Megaptera novaenangliae',
#  'Mesoplodon bowdoini',
#  'Mesoplodon densirostris',
#  'Mirounga leonina',
#  'Monachus monachus',
#  'Neomonachus schauinslandi',
#  'Neophoca cinerea',
#  'Neophocaena phocaenoides',
#  'Orcaella brevirostris',
#  'Orcaella heinsohni',
#  'Orcinus orca',
#  'Otaria byronia',
#  'Pagophilus groenlandicus',
#  'Peponocephala electra',
#  'Phoca vitulina',
#  'Phocarctos hookeri',
#  'Phocoena phocoena',
#  'Phocoena phocoena relicta',
#  'Phocoena sinus',
#  'Phocoena spinipinnis',
#  'Physeter macrocephalus',
#  'Pontoporia blainvillei',
#  'Pseudorca crassidens',
#  'Pusa caspica',
#  'Pusa hispida botnica',
#  'Pusa hispida ladogensis',
#  'Pusa hispida saimensis',
#  'Sotalia guianensis',
#  'Sousa chinensis',
#  'Sousa plumbea',
#  'Sousa sahulensis',
#  'Sousa teuszii',
#  'Stenella attenuata',
#  'Stenella clymene',
#  'Stenella coeruleoalba',
#  'Stenella longirostris',
#  'Steno bredanensis',
#  'Tasmacetus shepherdi',
#  'Trichechus manatus',
#  'Trichechus manatus latirostris',
#  'Trichechus manatus manatus',
#  'Tursiops aduncus',
#  'Tursiops erebennus',
#  'Tursiops truncatus',
#  'Tursiops truncatus gephyreus',
#  'Tursiops truncatus ponticus',
#  'Tursiops truncatus truncatus',
#  'Unconfirmed - pending further assessment',
#  'Zalophus californianus',
#  'Ziphius cavirostris'}
